# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# IMPORTING DATASET: (Patient Characteristics Survey (PCS): 2017)

# %%
df = pd.read_csv("https://data.ny.gov/resource/8itk-gcdy.csv")
df
# Out:
#      survey_year  ... three_digit_residence_zip
# 0           2017  ...                       100
# 1           2017  ...                       109
# 2           2017  ...                       109
# 3           2017  ...                       136
# 4           2017  ...                       147
# ..           ...  ...                       ...
# 995         2017  ...                       120
# 996         2017  ...                       999
# 997         2017  ...                       888
# 998         2017  ...                       116
# 999         2017  ...                       105
#
# [1000 rows x 67 columns]

# %% [markdown]
# **Continious Dependent Variable**
#   1. number of hours worked each week
#
# **3 Independent Variable with at least 3 levels**
#   1. Race (Black Only, White Only, Unknown Race)
#   2. Education Status (No Formal Education, Some College, College OR Graduate Degree)
#   3. Living Situation (Private Residence, Other Living Situation, Unknown)

# %% [markdown]
# ANOVA TESTING

# %%
sns.set_theme(style="whitegrid")
Patient_Characteristics_Survey_PCS_2017 = sns.load_dataset("Patient_Characteristics_Survey_PCS_2017")
ax = sns.boxplot(x=Race["Number Of Hours Worked Each Week"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-12c3692e3df1> in <module>()
#       1 sns.set_theme(style="whitegrid")
# ----> 2 Patient_Characteristics_Survey_PCS_2017 = sns.load_dataset("Patient_Characteristics_Survey_PCS_2017")
#       3 ax = sns.boxplot(x=Race["Number Of Hours Worked Each Week"])
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'Patient_Characteristics_Survey_PCS_2017' is not one of the example datasets.

# %% [markdown]
# Creating Assumptions

# %%
# From regression or Anova framework
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as smf

# %%
# DV ~ C(IV) +C(IV)
model = smf.ols(Number Of Hours Worked Each Week = C(Race)", data= df).fit()
stats.sharpio(model.resid)
# Out:
#   File "<ipython-input-27-5ffb025f8377>", line 2
#     model = smf.ols(Number Of Hours Worked Each Week = C(Race)", data= df).fit()
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Assumption Testing

# %%
race1 = dataset[dataset['race'] == 'Black Only']
race2 = dataset[dataset['race'] == 'White Only']
race3 = dataset[dataset['race'] == 'Unknown Race']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-0952ac167ee7> in <module>()
#       1 dataset = df.race
# ----> 2 race1 = dataset[dataset['race'] == 'Black Only']
#       3 race2 = dataset[dataset['race'] == 'White Only']
#       4 race3 = dataset[dataset['race'] == 'Unknown Race']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ...

# %%
plt.hist(race1['Number Of Hours Worked Each Week'])
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9f63ad917691> in <module>()
# ----> 1 plt.hist(race1['Number Of Hours Worked Each Week'])
#       2 plt.show
#
# NameError: name 'race1' is not defined

# %%
plt.hist(race2['Number Of Hours Worked Each Week'])
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-3483528af8a1> in <module>()
# ----> 1 plt.hist(race2['Number Of Hours Worked Each Week'])
#       2 plt.show
#
# NameError: name 'race2' is not defined

# %%
plt.hist(race1['Number Of Hours Worked Each Week'])
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-9f63ad917691> in <module>()
# ----> 1 plt.hist(race1['Number Of Hours Worked Each Week'])
#       2 plt.show
#
# NameError: name 'race1' is not defined

# %% [markdown]
# ANOVA TESTING 1 (Number of Hours worked each week and Race)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import statsmodels.formula.api as smf
import scipy.stats as stats

# %%
import statsmodels.api as sm

# %%
model = smf.ols("Number Of Hours Worked Each Week ~ C(Race)", data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#   File "<unknown>", line 1
#     Number Of Hours Worked Each Week
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ANOVA TESTING 2: Number of hours worked each week and Education Status

# %%
model = smf.ols("Number Of Hours Worked Each Week ~ C(Education Status)", data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#   File "<unknown>", line 1
#     Number Of Hours Worked Each Week
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ANOVA TESTING 3: Number of hours worked each week and Living Situation

# %%
model = smf.ols("Number Of Hours Worked Each Week ~ C(Living Situation)", data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#   File "<unknown>", line 1
#     Number Of Hours Worked Each Week
#             ^
# SyntaxError: invalid syntax
